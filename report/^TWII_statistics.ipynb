# %%
import pandas as pd
import matplotlib.pyplot as plt

# 讀取數據
taiwan_df = pd.read_csv('/Users/jennifer/Downloads/202001-202312_TWII.csv', parse_dates=['Date'])

# 計算基本統計量的函數
def calculate_statistics(df, column):
    return {
        'Mean': df[column].mean(),
        'Median': df[column].median(),
        'Standard Deviation': df[column].std(),
        'Max': df[column].max(),
        'Min': df[column].min(),
        '25th Percentile': df[column].quantile(0.25),
        '75th Percentile': df[column].quantile(0.75)
    }

# 計算台灣大盤的基本統計量
tsmc_stats = calculate_statistics(taiwan_df, 'Close')

print("台灣大盤基本統計量:")
for stat, value in tsmc_stats.items():
    print(f"{stat}: {value}")

# 繪製時間序列圖
plt.figure(figsize=(12, 6))
plt.plot(taiwan_df['Date'], taiwan_df['Close'], label='TSMC Stock Price', color='blue')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('TSMC Stock Price Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 台灣大盤基本統計量:
# Mean: 15245.7726125519
# Median: 15857.889648
# Standard Deviation: 2224.608788939358
# Max: 18526.349609
# Min: 8681.339844
# 25th Percentile: 13722.429688
# 75th Percentile: 17065.970703
